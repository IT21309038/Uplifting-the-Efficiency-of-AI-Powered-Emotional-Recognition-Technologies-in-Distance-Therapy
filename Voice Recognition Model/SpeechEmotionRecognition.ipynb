# %%
import os
import librosa
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report

from keras.models import Sequential
from keras.layers import Dense, Conv1D, MaxPooling1D, Dropout, LSTM, BatchNormalization, LeakyReLU
from keras.optimizers import Adam
from keras.callbacks import ReduceLROnPlateau, LearningRateScheduler

# Load RAVDESS data
Ravdess = "Data/Ravdess/audio_speech_actors_01-24/"
ravdess_directory_list = os.listdir(Ravdess)

file_emotion = []
file_path = []

for dir in ravdess_directory_list:
    actor = os.listdir(Ravdess + dir)
    for file in actor:
        part = file.split('.')[0].split('-')
        file_emotion.append(int(part[2]))
        file_path.append(Ravdess + dir + '/' + file)

emotion_df = pd.DataFrame(file_emotion, columns=['Emotions'])
path_df = pd.DataFrame(file_path, columns=['Path'])
Ravdess_df = pd.concat([emotion_df, path_df], axis=1)
Ravdess_df.Emotions.replace({
    1: 'neutral', 2: 'calm', 3: 'happy', 4: 'sad', 
    5: 'angry', 6: 'fear', 7: 'disgust', 8: 'surprise'}, inplace=True)

# Plot emotion distribution
plt.figure(figsize=(10, 6))
sns.countplot(data=Ravdess_df, x='Emotions', order=Ravdess_df['Emotions'].value_counts().index)
plt.title('Emotion Distribution in RAVDESS Dataset')
plt.xlabel('Emotions')
plt.ylabel('Count')
plt.show()

# Audio augmentation functions
def add_noise(data):
    noise_amp = 0.005 * np.random.uniform() * np.amax(data)
    return data + noise_amp * np.random.normal(size=data.shape[0])

def time_stretch(data, rate=0.9):
    return librosa.effects.time_stretch(data, rate=rate)

def pitch_shift(data, sampling_rate, steps=2):
    return librosa.effects.pitch_shift(data, sr=sampling_rate, n_steps=steps)

def random_crop(data, sampling_rate, duration=2.5):
    max_offset = len(data) - int(duration * sampling_rate)
    if max_offset > 0:
        offset = np.random.randint(0, max_offset)
        data = data[offset:offset + int(duration * sampling_rate)]
    return data

def reverse_audio(data):
    return data[::-1]

# Feature extraction function
def extract_features(data, sample_rate):
    result = np.array([])
    # Zero Crossing Rate
    zcr = np.mean(librosa.feature.zero_crossing_rate(y=data).T, axis=0)
    result = np.hstack((result, zcr))
    # Chroma STFT
    stft = np.abs(librosa.stft(data))
    chroma_stft = np.mean(librosa.feature.chroma_stft(S=stft, sr=sample_rate).T, axis=0)
    result = np.hstack((result, chroma_stft))
    # MFCC
    mfcc = np.mean(librosa.feature.mfcc(y=data, sr=sample_rate).T, axis=0)
    result = np.hstack((result, mfcc))
    # RMS
    rms = np.mean(librosa.feature.rms(y=data).T, axis=0)
    result = np.hstack((result, rms))
    # MelSpectrogram
    mel = np.mean(librosa.feature.melspectrogram(y=data, sr=sample_rate).T, axis=0)
    result = np.hstack((result, mel))
    return result

# Collect features and labels with augmentation
X, Y = [], []
for path, emotion in zip(Ravdess_df.Path, Ravdess_df.Emotions):
    data, sample_rate = librosa.load(path, duration=2.5, offset=0.6)

    # Original features
    features = extract_features(data, sample_rate)
    X.append(features)
    Y.append(emotion)

    # Augmented data
    augmented_data = [
        add_noise(data),
        time_stretch(data, rate=0.9),
        pitch_shift(data, sample_rate, steps=2),
        random_crop(data, sample_rate),
        reverse_audio(data)  # New augmentation
    ]

    for aug in augmented_data:
        features = extract_features(aug, sample_rate)
        X.append(features)
        Y.append(emotion)

# Plot the emotion distribution after augmentation
augmented_emotions = pd.DataFrame({'Emotions': Y})
plt.figure(figsize=(12, 6))
sns.countplot(data=augmented_emotions, x='Emotions', order=augmented_emotions['Emotions'].value_counts().index)
plt.title('Emotion Distribution After Data Augmentation')
plt.xlabel('Emotions')
plt.ylabel('Count')
plt.show()

# Convert to numpy array
X = np.array(X)
Y = np.array(Y)

# One-hot encoding for labels
encoder = OneHotEncoder()
Y = encoder.fit_transform(np.array(Y).reshape(-1, 1)).toarray()

# Train-test split
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42, shuffle=True)

# Standardize the features
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)
x_train = np.expand_dims(x_train, axis=2)
x_test = np.expand_dims(x_test, axis=2)

# Create the model
model = Sequential()

# Add Conv1D layers
model.add(Conv1D(256, kernel_size=5, strides=1, padding='same', input_shape=(x_train.shape[1], 1)))
model.add(LeakyReLU(alpha=0.2))
model.add(BatchNormalization())
model.add(MaxPooling1D(pool_size=5, strides=2, padding='same'))
model.add(Dropout(0.3))

model.add(Conv1D(256, kernel_size=5, strides=1, padding='same'))
model.add(LeakyReLU(alpha=0.2))
model.add(BatchNormalization())
model.add(MaxPooling1D(pool_size=5, strides=2, padding='same'))
model.add(Dropout(0.3))

# Add LSTM layers
model.add(LSTM(128, return_sequences=True))
model.add(Dropout(0.4))
model.add(LSTM(64, return_sequences=False))
model.add(BatchNormalization())

# Add Dense layers
model.add(Dense(128))
model.add(LeakyReLU(alpha=0.2))
model.add(BatchNormalization())
model.add(Dropout(0.5))

# Output layer
model.add(Dense(8, activation='softmax'))

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

# Cyclical learning rate scheduler
def scheduler(epoch, lr):
    if epoch < 30:
        return lr
    return lr * 0.8

lr_scheduler = LearningRateScheduler(scheduler)

# Train the model
history = model.fit(x_train, y_train, batch_size=64, epochs=100, validation_data=(x_test, y_test), callbacks=[lr_scheduler])

# Evaluate the model
test_loss, test_accuracy = model.evaluate(x_test, y_test, verbose=0)
print(f"Test Accuracy: {test_accuracy * 100:.2f}%")

# Plot training & validation loss and accuracy
epochs = range(len(history.history['accuracy']))

plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(epochs, history.history['loss'], label='Training Loss')
plt.plot(epochs, history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(epochs, history.history['accuracy'], label='Training Accuracy')
plt.plot(epochs, history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# Confusion Matrix
y_pred = np.argmax(model.predict(x_test), axis=1)
y_true = np.argmax(y_test, axis=1)

cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=encoder.categories_[0], yticklabels=encoder.categories_[0])
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()

# Classification Report
print("Classification Report:")
print(classification_report(y_true, y_pred, target_names=encoder.categories_[0]))
# Out:
# C:\Users\Thanish\AppData\Local\Temp\ipykernel_2488\2221293785.py:34: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Ravdess_df.Emotions.replace({
# C:\Users\Thanish\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# C:\Users\Thanish\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\activations\leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# Epoch 1/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 25s 187ms/step - accuracy: 0.1858 - loss: 2.5329 - val_accuracy: 0.1661 - val_loss: 2.0507 - learning_rate: 0.0010
# Epoch 2/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 21s 198ms/step - accuracy: 0.2335 - loss: 2.0327 - val_accuracy: 0.1892 - val_loss: 2.1025 - learning_rate: 0.0010
# Epoch 3/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 23s 211ms/step - accuracy: 0.2743 - loss: 1.9109 - val_accuracy: 0.1939 - val_loss: 2.1904 - learning_rate: 0.0010
# Epoch 4/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 18s 171ms/step - accuracy: 0.2949 - loss: 1.8427 - val_accuracy: 0.2622 - val_loss: 2.0334 - learning_rate: 0.0010
# Epoch 5/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 18s 170ms/step - accuracy: 0.3343 - loss: 1.7534 - val_accuracy: 0.2980 - val_loss: 1.9412 - learning_rate: 0.0010
# Epoch 6/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 19s 171ms/step - accuracy: 0.3794 - loss: 1.6427 - val_accuracy: 0.3287 - val_loss: 2.0668 - learning_rate: 0.0010
# Epoch 7/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 19s 173ms/step - accuracy: 0.3811 - loss: 1.6356 - val_accuracy: 0.3565 - val_loss: 1.7441 - learning_rate: 0.0010
# Epoch 8/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 24s 226ms/step - accuracy: 0.4081 - loss: 1.5803 - val_accuracy: 0.3744 - val_loss: 1.7665 - learning_rate: 0.0010
# Epoch 9/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 24s 222ms/step - accuracy: 0.4387 - loss: 1.5290 - val_accuracy: 0.3391 - val_loss: 1.9544 - learning_rate: 0.0010
# Epoch 10/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 20s 187ms/step - accuracy: 0.4628 - loss: 1.4530 - val_accuracy: 0.4578 - val_loss: 1.4492 - learning_rate: 0.0010
# Epoch 11/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 24s 224ms/step - accuracy: 0.4732 - loss: 1.4119 - val_accuracy: 0.4867 - val_loss: 1.3592 - learning_rate: 0.0010
# Epoch 12/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 21s 195ms/step - accuracy: 0.5125 - loss: 1.3350 - val_accuracy: 0.4630 - val_loss: 1.4300 - learning_rate: 0.0010
# Epoch 13/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 19s 175ms/step - accuracy: 0.5188 - loss: 1.2781 - val_accuracy: 0.5179 - val_loss: 1.3352 - learning_rate: 0.0010
# Epoch 14/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 20s 186ms/step - accuracy: 0.5209 - loss: 1.2885 - val_accuracy: 0.5527 - val_loss: 1.2255 - learning_rate: 0.0010
# Epoch 15/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 23s 211ms/step - accuracy: 0.5518 - loss: 1.2133 - val_accuracy: 0.5816 - val_loss: 1.1542 - learning_rate: 0.0010
# Epoch 16/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 24s 225ms/step - accuracy: 0.5812 - loss: 1.1637 - val_accuracy: 0.4873 - val_loss: 1.7762 - learning_rate: 0.0010
# Epoch 17/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 22s 201ms/step - accuracy: 0.5803 - loss: 1.1524 - val_accuracy: 0.5741 - val_loss: 1.1938 - learning_rate: 0.0010
# Epoch 18/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 22s 200ms/step - accuracy: 0.6209 - loss: 1.0421 - val_accuracy: 0.4844 - val_loss: 1.6553 - learning_rate: 0.0010
# Epoch 19/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 21s 198ms/step - accuracy: 0.6070 - loss: 1.0595 - val_accuracy: 0.6059 - val_loss: 1.1442 - learning_rate: 0.0010
# Epoch 20/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 21s 194ms/step - accuracy: 0.6541 - loss: 0.9631 - val_accuracy: 0.6516 - val_loss: 0.9583 - learning_rate: 0.0010
# Epoch 21/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 20s 188ms/step - accuracy: 0.6712 - loss: 0.9056 - val_accuracy: 0.6568 - val_loss: 0.9616 - learning_rate: 0.0010
# Epoch 22/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 19s 180ms/step - accuracy: 0.6776 - loss: 0.8704 - val_accuracy: 0.6481 - val_loss: 0.9529 - learning_rate: 0.0010
# Epoch 23/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 19s 179ms/step - accuracy: 0.7017 - loss: 0.8410 - val_accuracy: 0.5828 - val_loss: 1.1565 - learning_rate: 0.0010
# Epoch 24/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 20s 186ms/step - accuracy: 0.7112 - loss: 0.8043 - val_accuracy: 0.6834 - val_loss: 1.0021 - learning_rate: 0.0010
# Epoch 25/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 22s 204ms/step - accuracy: 0.7440 - loss: 0.7354 - val_accuracy: 0.7106 - val_loss: 0.7731 - learning_rate: 0.0010
# Epoch 26/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 24s 224ms/step - accuracy: 0.7439 - loss: 0.7047 - val_accuracy: 0.7338 - val_loss: 0.7635 - learning_rate: 0.0010
# Epoch 27/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 25s 234ms/step - accuracy: 0.7583 - loss: 0.6754 - val_accuracy: 0.7789 - val_loss: 0.6515 - learning_rate: 0.0010
# Epoch 28/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 22s 202ms/step - accuracy: 0.7806 - loss: 0.6350 - val_accuracy: 0.7610 - val_loss: 0.6956 - learning_rate: 0.0010
# Epoch 29/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 21s 194ms/step - accuracy: 0.7873 - loss: 0.6051 - val_accuracy: 0.7095 - val_loss: 0.8428 - learning_rate: 0.0010
# Epoch 30/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 23s 217ms/step - accuracy: 0.7979 - loss: 0.5794 - val_accuracy: 0.6881 - val_loss: 1.1220 - learning_rate: 0.0010
# Epoch 31/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 27s 250ms/step - accuracy: 0.8238 - loss: 0.5064 - val_accuracy: 0.7604 - val_loss: 0.7983 - learning_rate: 8.0000e-04
# Epoch 32/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 37s 216ms/step - accuracy: 0.8577 - loss: 0.4323 - val_accuracy: 0.8038 - val_loss: 0.6788 - learning_rate: 6.4000e-04
# Epoch 33/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 25s 231ms/step - accuracy: 0.8769 - loss: 0.3693 - val_accuracy: 0.8212 - val_loss: 0.5826 - learning_rate: 5.1200e-04
# Epoch 34/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 21s 196ms/step - accuracy: 0.8865 - loss: 0.3437 - val_accuracy: 0.8681 - val_loss: 0.4545 - learning_rate: 4.0960e-04
# Epoch 35/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 21s 192ms/step - accuracy: 0.8980 - loss: 0.3104 - val_accuracy: 0.8328 - val_loss: 0.5406 - learning_rate: 3.2768e-04
# Epoch 36/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 20s 188ms/step - accuracy: 0.8954 - loss: 0.3092 - val_accuracy: 0.8600 - val_loss: 0.4743 - learning_rate: 2.6214e-04
# Epoch 37/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 22s 203ms/step - accuracy: 0.9136 - loss: 0.2677 - val_accuracy: 0.8756 - val_loss: 0.4129 - learning_rate: 2.0972e-04
# Epoch 38/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 25s 229ms/step - accuracy: 0.9137 - loss: 0.2690 - val_accuracy: 0.8762 - val_loss: 0.4378 - learning_rate: 1.6777e-04
# Epoch 39/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 25s 233ms/step - accuracy: 0.9195 - loss: 0.2418 - val_accuracy: 0.8791 - val_loss: 0.4474 - learning_rate: 1.3422e-04
# Epoch 40/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 21s 197ms/step - accuracy: 0.9211 - loss: 0.2378 - val_accuracy: 0.8843 - val_loss: 0.4050 - learning_rate: 1.0737e-04
# Epoch 41/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 22s 201ms/step - accuracy: 0.9305 - loss: 0.2109 - val_accuracy: 0.8924 - val_loss: 0.3895 - learning_rate: 8.5899e-05
# Epoch 42/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 24s 225ms/step - accuracy: 0.9331 - loss: 0.2171 - val_accuracy: 0.8900 - val_loss: 0.3997 - learning_rate: 6.8719e-05
# Epoch 43/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 21s 191ms/step - accuracy: 0.9365 - loss: 0.1942 - val_accuracy: 0.8895 - val_loss: 0.4005 - learning_rate: 5.4976e-05
# Epoch 44/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 21s 192ms/step - accuracy: 0.9350 - loss: 0.1978 - val_accuracy: 0.8895 - val_loss: 0.3987 - learning_rate: 4.3980e-05
# Epoch 45/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 21s 191ms/step - accuracy: 0.9332 - loss: 0.2057 - val_accuracy: 0.8895 - val_loss: 0.4085 - learning_rate: 3.5184e-05
# Epoch 46/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 48s 444ms/step - accuracy: 0.9417 - loss: 0.1795 - val_accuracy: 0.8883 - val_loss: 0.3972 - learning_rate: 2.8147e-05
# Epoch 47/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 22s 202ms/step - accuracy: 0.9333 - loss: 0.2099 - val_accuracy: 0.8941 - val_loss: 0.3973 - learning_rate: 2.2518e-05
# Epoch 48/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 23s 215ms/step - accuracy: 0.9364 - loss: 0.1930 - val_accuracy: 0.8941 - val_loss: 0.3968 - learning_rate: 1.8014e-05
# Epoch 49/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 24s 221ms/step - accuracy: 0.9401 - loss: 0.1822 - val_accuracy: 0.8912 - val_loss: 0.3988 - learning_rate: 1.4412e-05
# Epoch 50/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 25s 233ms/step - accuracy: 0.9295 - loss: 0.2149 - val_accuracy: 0.8941 - val_loss: 0.3976 - learning_rate: 1.1529e-05
# Epoch 51/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 23s 209ms/step - accuracy: 0.9363 - loss: 0.1918 - val_accuracy: 0.8935 - val_loss: 0.3992 - learning_rate: 9.2234e-06
# Epoch 52/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 23s 212ms/step - accuracy: 0.9459 - loss: 0.1749 - val_accuracy: 0.8935 - val_loss: 0.3973 - learning_rate: 7.3787e-06
# Epoch 53/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 23s 212ms/step - accuracy: 0.9336 - loss: 0.1932 - val_accuracy: 0.8924 - val_loss: 0.3996 - learning_rate: 5.9030e-06
# Epoch 54/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 24s 219ms/step - accuracy: 0.9390 - loss: 0.1985 - val_accuracy: 0.8935 - val_loss: 0.3997 - learning_rate: 4.7224e-06
# Epoch 55/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 23s 216ms/step - accuracy: 0.9362 - loss: 0.1909 - val_accuracy: 0.8924 - val_loss: 0.3993 - learning_rate: 3.7779e-06
# Epoch 56/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 21s 192ms/step - accuracy: 0.9361 - loss: 0.1979 - val_accuracy: 0.8918 - val_loss: 0.3998 - learning_rate: 3.0223e-06
# Epoch 57/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 24s 225ms/step - accuracy: 0.9413 - loss: 0.1749 - val_accuracy: 0.8924 - val_loss: 0.3984 - learning_rate: 2.4179e-06
# Epoch 58/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 25s 230ms/step - accuracy: 0.9377 - loss: 0.1888 - val_accuracy: 0.8941 - val_loss: 0.3980 - learning_rate: 1.9343e-06
# Epoch 59/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 23s 215ms/step - accuracy: 0.9342 - loss: 0.2075 - val_accuracy: 0.8918 - val_loss: 0.3976 - learning_rate: 1.5474e-06
# Epoch 60/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 25s 229ms/step - accuracy: 0.9360 - loss: 0.1976 - val_accuracy: 0.8918 - val_loss: 0.3974 - learning_rate: 1.2379e-06
# Epoch 61/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 25s 230ms/step - accuracy: 0.9271 - loss: 0.2114 - val_accuracy: 0.8929 - val_loss: 0.3984 - learning_rate: 9.9035e-07
# Epoch 62/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 22s 203ms/step - accuracy: 0.9360 - loss: 0.1962 - val_accuracy: 0.8918 - val_loss: 0.3990 - learning_rate: 7.9228e-07
# Epoch 63/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 24s 222ms/step - accuracy: 0.9390 - loss: 0.1842 - val_accuracy: 0.8918 - val_loss: 0.3984 - learning_rate: 6.3383e-07
# Epoch 64/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 26s 244ms/step - accuracy: 0.9353 - loss: 0.1995 - val_accuracy: 0.8918 - val_loss: 0.3973 - learning_rate: 5.0706e-07
# Epoch 65/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 27s 252ms/step - accuracy: 0.9388 - loss: 0.1794 - val_accuracy: 0.8924 - val_loss: 0.3981 - learning_rate: 4.0565e-07
# Epoch 66/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 25s 234ms/step - accuracy: 0.9349 - loss: 0.2022 - val_accuracy: 0.8924 - val_loss: 0.3979 - learning_rate: 3.2452e-07
# Epoch 67/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 22s 200ms/step - accuracy: 0.9409 - loss: 0.1820 - val_accuracy: 0.8918 - val_loss: 0.3977 - learning_rate: 2.5961e-07
# Epoch 68/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 25s 236ms/step - accuracy: 0.9314 - loss: 0.2055 - val_accuracy: 0.8924 - val_loss: 0.3975 - learning_rate: 2.0769e-07
# Epoch 69/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 22s 203ms/step - accuracy: 0.9350 - loss: 0.1955 - val_accuracy: 0.8935 - val_loss: 0.3983 - learning_rate: 1.6615e-07
# Epoch 70/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 22s 203ms/step - accuracy: 0.9278 - loss: 0.2092 - val_accuracy: 0.8929 - val_loss: 0.3982 - learning_rate: 1.3292e-07
# Epoch 71/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 23s 213ms/step - accuracy: 0.9363 - loss: 0.1944 - val_accuracy: 0.8929 - val_loss: 0.3978 - learning_rate: 1.0634e-07
# Epoch 72/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 24s 218ms/step - accuracy: 0.9324 - loss: 0.1996 - val_accuracy: 0.8929 - val_loss: 0.3984 - learning_rate: 8.5071e-08
# Epoch 73/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 24s 225ms/step - accuracy: 0.9323 - loss: 0.2085 - val_accuracy: 0.8929 - val_loss: 0.3979 - learning_rate: 6.8056e-08
# Epoch 74/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 23s 214ms/step - accuracy: 0.9364 - loss: 0.1955 - val_accuracy: 0.8929 - val_loss: 0.3979 - learning_rate: 5.4445e-08
# Epoch 75/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 23s 210ms/step - accuracy: 0.9413 - loss: 0.1834 - val_accuracy: 0.8918 - val_loss: 0.3987 - learning_rate: 4.3556e-08
# Epoch 76/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 24s 223ms/step - accuracy: 0.9334 - loss: 0.1962 - val_accuracy: 0.8929 - val_loss: 0.3989 - learning_rate: 3.4845e-08
# Epoch 77/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 22s 205ms/step - accuracy: 0.9331 - loss: 0.2030 - val_accuracy: 0.8924 - val_loss: 0.3986 - learning_rate: 2.7876e-08
# Epoch 78/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 23s 209ms/step - accuracy: 0.9364 - loss: 0.2029 - val_accuracy: 0.8929 - val_loss: 0.3975 - learning_rate: 2.2301e-08
# Epoch 79/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 23s 215ms/step - accuracy: 0.9254 - loss: 0.2081 - val_accuracy: 0.8941 - val_loss: 0.3983 - learning_rate: 1.7841e-08
# Epoch 80/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 25s 233ms/step - accuracy: 0.9333 - loss: 0.2029 - val_accuracy: 0.8935 - val_loss: 0.3992 - learning_rate: 1.4272e-08
# Epoch 81/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 23s 209ms/step - accuracy: 0.9387 - loss: 0.1934 - val_accuracy: 0.8929 - val_loss: 0.3981 - learning_rate: 1.1418e-08
# Epoch 82/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 22s 207ms/step - accuracy: 0.9412 - loss: 0.1802 - val_accuracy: 0.8918 - val_loss: 0.3975 - learning_rate: 9.1344e-09
# Epoch 83/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 23s 216ms/step - accuracy: 0.9361 - loss: 0.1913 - val_accuracy: 0.8935 - val_loss: 0.3984 - learning_rate: 7.3075e-09
# Epoch 84/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 24s 223ms/step - accuracy: 0.9363 - loss: 0.1889 - val_accuracy: 0.8929 - val_loss: 0.3983 - learning_rate: 5.8460e-09
# Epoch 85/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 25s 230ms/step - accuracy: 0.9417 - loss: 0.1778 - val_accuracy: 0.8929 - val_loss: 0.3982 - learning_rate: 4.6768e-09
# Epoch 86/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 23s 210ms/step - accuracy: 0.9391 - loss: 0.2038 - val_accuracy: 0.8924 - val_loss: 0.3980 - learning_rate: 3.7414e-09
# Epoch 87/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 23s 209ms/step - accuracy: 0.9435 - loss: 0.1814 - val_accuracy: 0.8929 - val_loss: 0.3981 - learning_rate: 2.9932e-09
# Epoch 88/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 23s 214ms/step - accuracy: 0.9399 - loss: 0.1915 - val_accuracy: 0.8929 - val_loss: 0.3973 - learning_rate: 2.3945e-09
# Epoch 89/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 22s 202ms/step - accuracy: 0.9404 - loss: 0.1970 - val_accuracy: 0.8924 - val_loss: 0.3976 - learning_rate: 1.9156e-09
# Epoch 90/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 22s 201ms/step - accuracy: 0.9372 - loss: 0.1924 - val_accuracy: 0.8929 - val_loss: 0.3976 - learning_rate: 1.5325e-09
# Epoch 91/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 22s 205ms/step - accuracy: 0.9364 - loss: 0.1895 - val_accuracy: 0.8929 - val_loss: 0.3979 - learning_rate: 1.2260e-09
# Epoch 92/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 22s 207ms/step - accuracy: 0.9435 - loss: 0.1971 - val_accuracy: 0.8935 - val_loss: 0.3981 - learning_rate: 9.8080e-10
# Epoch 93/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 22s 204ms/step - accuracy: 0.9298 - loss: 0.1991 - val_accuracy: 0.8929 - val_loss: 0.3976 - learning_rate: 7.8464e-10
# Epoch 94/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 22s 203ms/step - accuracy: 0.9328 - loss: 0.2014 - val_accuracy: 0.8924 - val_loss: 0.3979 - learning_rate: 6.2771e-10
# Epoch 95/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 22s 201ms/step - accuracy: 0.9424 - loss: 0.1858 - val_accuracy: 0.8935 - val_loss: 0.3984 - learning_rate: 5.0217e-10
# Epoch 96/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 22s 202ms/step - accuracy: 0.9384 - loss: 0.1866 - val_accuracy: 0.8929 - val_loss: 0.3988 - learning_rate: 4.0173e-10
# Epoch 97/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 23s 211ms/step - accuracy: 0.9313 - loss: 0.2072 - val_accuracy: 0.8924 - val_loss: 0.3979 - learning_rate: 3.2139e-10
# Epoch 98/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 22s 206ms/step - accuracy: 0.9423 - loss: 0.1794 - val_accuracy: 0.8935 - val_loss: 0.3983 - learning_rate: 2.5711e-10
# Epoch 99/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 23s 214ms/step - accuracy: 0.9381 - loss: 0.1828 - val_accuracy: 0.8929 - val_loss: 0.3982 - learning_rate: 2.0569e-10
# Epoch 100/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 27s 250ms/step - accuracy: 0.9369 - loss: 0.1968 - val_accuracy: 0.8924 - val_loss: 0.3979 - learning_rate: 1.6455e-10
# Test Accuracy: 89.24%
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#        angry       0.94      0.91      0.92       225
#         calm       0.95      0.90      0.93       220
#      disgust       0.91      0.90      0.90       235
#         fear       0.91      0.91      0.91       215
#        happy       0.86      0.88      0.87       247
#      neutral       0.70      0.95      0.81        98
#          sad       0.88      0.84      0.86       230
#     surprise       0.92      0.88      0.90       258
#
#     accuracy                           0.89      1728
#    macro avg       0.88      0.90      0.89      1728
# weighted avg       0.90      0.89      0.89      1728

# %%
import os
import librosa
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report

from keras.models import Sequential
from keras.layers import Dense, Conv1D, MaxPooling1D, Dropout, LSTM, BatchNormalization, LeakyReLU
from keras.optimizers import Adam
from keras.callbacks import ReduceLROnPlateau, LearningRateScheduler

# Load RAVDESS data
Ravdess = "Data/Ravdess/audio_speech_actors_01-24/"
ravdess_directory_list = os.listdir(Ravdess)

file_emotion = []
file_path = []

for dir in ravdess_directory_list:
    actor = os.listdir(Ravdess + dir)
    for file in actor:
        part = file.split('.')[0].split('-')
        file_emotion.append(int(part[2]))
        file_path.append(Ravdess + dir + '/' + file)

emotion_df = pd.DataFrame(file_emotion, columns=['Emotions'])
path_df = pd.DataFrame(file_path, columns=['Path'])
Ravdess_df = pd.concat([emotion_df, path_df], axis=1)
Ravdess_df.Emotions.replace({
    1: 'neutral', 2: 'calm', 3: 'happy', 4: 'sad', 
    5: 'angry', 6: 'fear', 7: 'disgust', 8: 'surprise'}, inplace=True)

# Plot emotion distribution
plt.figure(figsize=(10, 6))
sns.countplot(data=Ravdess_df, x='Emotions', order=Ravdess_df['Emotions'].value_counts().index)
plt.title('Emotion Distribution in RAVDESS Dataset')
plt.xlabel('Emotions')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\Thanish\AppData\Local\Temp\ipykernel_21908\668648010.py:34: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Ravdess_df.Emotions.replace({

# %%
# Audio augmentation functions
def add_noise(data):
    noise_amp = 0.005 * np.random.uniform() * np.amax(data)
    return data + noise_amp * np.random.normal(size=data.shape[0])

def time_stretch(data, rate=0.9):
    return librosa.effects.time_stretch(data, rate=rate)

def pitch_shift(data, sampling_rate, steps=2):
    return librosa.effects.pitch_shift(data, sr=sampling_rate, n_steps=steps)

def random_crop(data, sampling_rate, duration=2.5):
    max_offset = len(data) - int(duration * sampling_rate)
    if max_offset > 0:
        offset = np.random.randint(0, max_offset)
        data = data[offset:offset + int(duration * sampling_rate)]
    return data

def reverse_audio(data):
    return data[::-1]

# Feature extraction function
def extract_features(data, sample_rate):
    result = np.array([])
    # Zero Crossing Rate
    zcr = np.mean(librosa.feature.zero_crossing_rate(y=data).T, axis=0)
    result = np.hstack((result, zcr))
    # Chroma STFT
    stft = np.abs(librosa.stft(data))
    chroma_stft = np.mean(librosa.feature.chroma_stft(S=stft, sr=sample_rate).T, axis=0)
    result = np.hstack((result, chroma_stft))
    # MFCC
    mfcc = np.mean(librosa.feature.mfcc(y=data, sr=sample_rate).T, axis=0)
    result = np.hstack((result, mfcc))
    # RMS
    rms = np.mean(librosa.feature.rms(y=data).T, axis=0)
    result = np.hstack((result, rms))
    # MelSpectrogram
    mel = np.mean(librosa.feature.melspectrogram(y=data, sr=sample_rate).T, axis=0)
    result = np.hstack((result, mel))
    return result

# Collect features and labels with augmentation
X, Y = [], []
for path, emotion in zip(Ravdess_df.Path, Ravdess_df.Emotions):
    data, sample_rate = librosa.load(path, duration=2.5, offset=0.6)

    # Original features
    features = extract_features(data, sample_rate)
    X.append(features)
    Y.append(emotion)

    # Augmented data
    augmented_data = [
        add_noise(data),
        time_stretch(data, rate=0.9),
        pitch_shift(data, sample_rate, steps=2),
        random_crop(data, sample_rate),
        reverse_audio(data)  # New augmentation
    ]

    for aug in augmented_data:
        features = extract_features(aug, sample_rate)
        X.append(features)
        Y.append(emotion)

# Plot the emotion distribution after augmentation
augmented_emotions = pd.DataFrame({'Emotions': Y})
plt.figure(figsize=(12, 6))
sns.countplot(data=augmented_emotions, x='Emotions', order=augmented_emotions['Emotions'].value_counts().index)
plt.title('Emotion Distribution After Data Augmentation')
plt.xlabel('Emotions')
plt.ylabel('Count')
plt.show()

# %%
# Convert to numpy array
X = np.array(X)
Y = np.array(Y)

# One-hot encoding for labels
encoder = OneHotEncoder()
Y = encoder.fit_transform(np.array(Y).reshape(-1, 1)).toarray()

# Train-test split
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42, shuffle=True)

# Standardize the features
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)
x_train = np.expand_dims(x_train, axis=2)
x_test = np.expand_dims(x_test, axis=2)

# Create the model
model = Sequential()

# Add Conv1D layers
model.add(Conv1D(256, kernel_size=5, strides=1, padding='same', input_shape=(x_train.shape[1], 1)))
model.add(LeakyReLU(alpha=0.2))
model.add(BatchNormalization())
model.add(MaxPooling1D(pool_size=5, strides=2, padding='same'))
model.add(Dropout(0.3))

model.add(Conv1D(256, kernel_size=5, strides=1, padding='same'))
model.add(LeakyReLU(alpha=0.2))
model.add(BatchNormalization())
model.add(MaxPooling1D(pool_size=5, strides=2, padding='same'))
model.add(Dropout(0.3))

# Add LSTM layers
model.add(LSTM(128, return_sequences=True))
model.add(Dropout(0.4))
model.add(LSTM(64, return_sequences=False))
model.add(BatchNormalization())

# Add Dense layers
model.add(Dense(128))
model.add(LeakyReLU(alpha=0.2))
model.add(BatchNormalization())
model.add(Dropout(0.5))

# Output layer
model.add(Dense(8, activation='softmax'))

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# C:\Users\Thanish\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# C:\Users\Thanish\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\activations\leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv1d_2 (Conv1D)                    │ (None, 162, 256)            │           1,536 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_3 (LeakyReLU)            │ (None, 162, 256)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_4                │ (None, 162, 256)            │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling1d_2 (MaxPooling1D)       │ (None, 81, 256)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 81, 256)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d_3 (Conv1D)                    │ (None, 81, 256)             │         327,936 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_4 (LeakyReLU)            │ (None, 81, 256)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_5                │ (None, 81, 256)             │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling1d_3 (MaxPooling1D)       │ (None, 41, 256)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_5 (Dropout)                  │ (None, 41, 256)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_2 (LSTM)                        │ (None, 41, 128)             │         197,120 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_6 (Dropout)                  │ (None, 41, 128)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_3 (LSTM)                        │ (None, 64)                  │          49,408 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_6                │ (None, 64)                  │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 128)                 │           8,320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_5 (LeakyReLU)            │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_7                │ (None, 128)                 │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_7 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 8)                   │           1,032 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 588,168 (2.24 MB)
#  Trainable params: 586,760 (2.24 MB)
#  Non-trainable params: 1,408 (5.50 KB)

# %%
# Cyclical learning rate scheduler
def scheduler(epoch, lr):
    if epoch < 30:
        return lr
    return lr * 0.8

lr_scheduler = LearningRateScheduler(scheduler)

# Train the model
history = model.fit(x_train, y_train, batch_size=64, epochs=100, validation_data=(x_test, y_test), callbacks=[lr_scheduler])

# Evaluate the model
test_loss, test_accuracy = model.evaluate(x_test, y_test, verbose=0)
print(f"Test Accuracy: {test_accuracy * 100:.2f}%")

# Plot training & validation loss and accuracy
epochs = range(len(history.history['accuracy']))

plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(epochs, history.history['loss'], label='Training Loss')
plt.plot(epochs, history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(epochs, history.history['accuracy'], label='Training Accuracy')
plt.plot(epochs, history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# Confusion Matrix
y_pred = np.argmax(model.predict(x_test), axis=1)
y_true = np.argmax(y_test, axis=1)

cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=encoder.categories_[0], yticklabels=encoder.categories_[0])
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()

# Classification Report
print("Classification Report:")
print(classification_report(y_true, y_pred, target_names=encoder.categories_[0]))
# Out:
# Epoch 1/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 20s 155ms/step - accuracy: 0.1900 - loss: 2.5469 - val_accuracy: 0.2135 - val_loss: 2.0111 - learning_rate: 0.0010
# Epoch 2/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 16s 148ms/step - accuracy: 0.2457 - loss: 2.0581 - val_accuracy: 0.1898 - val_loss: 2.1503 - learning_rate: 0.0010
# Epoch 3/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 16s 151ms/step - accuracy: 0.2886 - loss: 1.9269 - val_accuracy: 0.2407 - val_loss: 2.1778 - learning_rate: 0.0010
# Epoch 4/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 18s 171ms/step - accuracy: 0.3246 - loss: 1.8090 - val_accuracy: 0.2384 - val_loss: 2.2400 - learning_rate: 0.0010
# Epoch 5/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 17s 161ms/step - accuracy: 0.3449 - loss: 1.7504 - val_accuracy: 0.2743 - val_loss: 2.0920 - learning_rate: 0.0010
# Epoch 6/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 18s 167ms/step - accuracy: 0.3681 - loss: 1.6454 - val_accuracy: 0.4410 - val_loss: 1.5266 - learning_rate: 0.0010
# Epoch 7/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 20s 182ms/step - accuracy: 0.4111 - loss: 1.5695 - val_accuracy: 0.4184 - val_loss: 1.5698 - learning_rate: 0.0010
# Epoch 8/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 19s 179ms/step - accuracy: 0.4156 - loss: 1.5444 - val_accuracy: 0.4508 - val_loss: 1.4725 - learning_rate: 0.0010
# Epoch 9/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 18s 169ms/step - accuracy: 0.4484 - loss: 1.4705 - val_accuracy: 0.3571 - val_loss: 1.8507 - learning_rate: 0.0010
# Epoch 10/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 18s 171ms/step - accuracy: 0.4704 - loss: 1.4303 - val_accuracy: 0.4751 - val_loss: 1.4117 - learning_rate: 0.0010
# Epoch 11/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 19s 172ms/step - accuracy: 0.4749 - loss: 1.4051 - val_accuracy: 0.4902 - val_loss: 1.3371 - learning_rate: 0.0010
# Epoch 12/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 19s 173ms/step - accuracy: 0.4995 - loss: 1.3446 - val_accuracy: 0.4954 - val_loss: 1.3959 - learning_rate: 0.0010
# Epoch 13/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 19s 173ms/step - accuracy: 0.4988 - loss: 1.3328 - val_accuracy: 0.5098 - val_loss: 1.2996 - learning_rate: 0.0010
# Epoch 14/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 19s 172ms/step - accuracy: 0.5318 - loss: 1.2604 - val_accuracy: 0.5573 - val_loss: 1.2099 - learning_rate: 0.0010
# Epoch 15/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 19s 173ms/step - accuracy: 0.5446 - loss: 1.2206 - val_accuracy: 0.5208 - val_loss: 1.2771 - learning_rate: 0.0010
# Epoch 16/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 19s 171ms/step - accuracy: 0.5606 - loss: 1.1803 - val_accuracy: 0.5833 - val_loss: 1.1129 - learning_rate: 0.0010
# Epoch 17/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 19s 173ms/step - accuracy: 0.5973 - loss: 1.0999 - val_accuracy: 0.5938 - val_loss: 1.1369 - learning_rate: 0.0010
# Epoch 18/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 18s 170ms/step - accuracy: 0.6001 - loss: 1.0805 - val_accuracy: 0.5938 - val_loss: 1.1116 - learning_rate: 0.0010
# Epoch 19/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 18s 169ms/step - accuracy: 0.6400 - loss: 0.9879 - val_accuracy: 0.6447 - val_loss: 0.9819 - learning_rate: 0.0010
# Epoch 20/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 18s 171ms/step - accuracy: 0.6461 - loss: 0.9738 - val_accuracy: 0.5237 - val_loss: 1.3042 - learning_rate: 0.0010
# Epoch 21/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 19s 172ms/step - accuracy: 0.6762 - loss: 0.9264 - val_accuracy: 0.6644 - val_loss: 0.9320 - learning_rate: 0.0010
# Epoch 22/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 19s 172ms/step - accuracy: 0.6960 - loss: 0.8560 - val_accuracy: 0.6863 - val_loss: 0.9037 - learning_rate: 0.0010
# Epoch 23/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 19s 172ms/step - accuracy: 0.7040 - loss: 0.8223 - val_accuracy: 0.6458 - val_loss: 0.9929 - learning_rate: 0.0010
# Epoch 24/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 19s 171ms/step - accuracy: 0.7452 - loss: 0.7338 - val_accuracy: 0.7292 - val_loss: 0.7663 - learning_rate: 0.0010
# Epoch 25/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 19s 171ms/step - accuracy: 0.7366 - loss: 0.7353 - val_accuracy: 0.7593 - val_loss: 0.7385 - learning_rate: 0.0010
# Epoch 26/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 18s 171ms/step - accuracy: 0.7658 - loss: 0.6662 - val_accuracy: 0.6331 - val_loss: 1.0711 - learning_rate: 0.0010
# Epoch 27/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 18s 171ms/step - accuracy: 0.7708 - loss: 0.6489 - val_accuracy: 0.7529 - val_loss: 0.6796 - learning_rate: 0.0010
# Epoch 28/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 19s 173ms/step - accuracy: 0.7999 - loss: 0.5849 - val_accuracy: 0.7286 - val_loss: 0.7963 - learning_rate: 0.0010
# Epoch 29/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 19s 173ms/step - accuracy: 0.7964 - loss: 0.6048 - val_accuracy: 0.7760 - val_loss: 0.6743 - learning_rate: 0.0010
# Epoch 30/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 18s 170ms/step - accuracy: 0.8105 - loss: 0.5435 - val_accuracy: 0.7894 - val_loss: 0.6601 - learning_rate: 0.0010
# Epoch 31/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 19s 171ms/step - accuracy: 0.8418 - loss: 0.4447 - val_accuracy: 0.8073 - val_loss: 0.6025 - learning_rate: 8.0000e-04
# Epoch 32/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 19s 173ms/step - accuracy: 0.8545 - loss: 0.4282 - val_accuracy: 0.8663 - val_loss: 0.4361 - learning_rate: 6.4000e-04
# Epoch 33/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 19s 171ms/step - accuracy: 0.8898 - loss: 0.3402 - val_accuracy: 0.8675 - val_loss: 0.4502 - learning_rate: 5.1200e-04
# Epoch 34/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 19s 172ms/step - accuracy: 0.8959 - loss: 0.3094 - val_accuracy: 0.8657 - val_loss: 0.4556 - learning_rate: 4.0960e-04
# Epoch 35/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 19s 173ms/step - accuracy: 0.8989 - loss: 0.2825 - val_accuracy: 0.8814 - val_loss: 0.3918 - learning_rate: 3.2768e-04
# Epoch 36/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 19s 174ms/step - accuracy: 0.9202 - loss: 0.2475 - val_accuracy: 0.8738 - val_loss: 0.4252 - learning_rate: 2.6214e-04
# Epoch 37/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 19s 174ms/step - accuracy: 0.9165 - loss: 0.2480 - val_accuracy: 0.8837 - val_loss: 0.4065 - learning_rate: 2.0972e-04
# Epoch 38/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 19s 175ms/step - accuracy: 0.9263 - loss: 0.2149 - val_accuracy: 0.8872 - val_loss: 0.3837 - learning_rate: 1.6777e-04
# Epoch 39/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 19s 174ms/step - accuracy: 0.9313 - loss: 0.2054 - val_accuracy: 0.8872 - val_loss: 0.3768 - learning_rate: 1.3422e-04
# Epoch 40/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 19s 174ms/step - accuracy: 0.9322 - loss: 0.2127 - val_accuracy: 0.8860 - val_loss: 0.3912 - learning_rate: 1.0737e-04
# Epoch 41/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 19s 172ms/step - accuracy: 0.9294 - loss: 0.2176 - val_accuracy: 0.8953 - val_loss: 0.3635 - learning_rate: 8.5899e-05
# Epoch 42/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 19s 172ms/step - accuracy: 0.9302 - loss: 0.2046 - val_accuracy: 0.8970 - val_loss: 0.3611 - learning_rate: 6.8719e-05
# Epoch 43/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 19s 174ms/step - accuracy: 0.9363 - loss: 0.1972 - val_accuracy: 0.8981 - val_loss: 0.3593 - learning_rate: 5.4976e-05
# Epoch 44/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 19s 173ms/step - accuracy: 0.9369 - loss: 0.1911 - val_accuracy: 0.8987 - val_loss: 0.3611 - learning_rate: 4.3980e-05
# Epoch 45/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 19s 175ms/step - accuracy: 0.9347 - loss: 0.1916 - val_accuracy: 0.8981 - val_loss: 0.3556 - learning_rate: 3.5184e-05
# Epoch 46/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 19s 179ms/step - accuracy: 0.9451 - loss: 0.1728 - val_accuracy: 0.8964 - val_loss: 0.3617 - learning_rate: 2.8147e-05
# Epoch 47/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 22s 193ms/step - accuracy: 0.9401 - loss: 0.1838 - val_accuracy: 0.8953 - val_loss: 0.3649 - learning_rate: 2.2518e-05
# Epoch 48/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 19s 173ms/step - accuracy: 0.9454 - loss: 0.1776 - val_accuracy: 0.8981 - val_loss: 0.3604 - learning_rate: 1.8014e-05
# Epoch 49/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 19s 174ms/step - accuracy: 0.9402 - loss: 0.1939 - val_accuracy: 0.8964 - val_loss: 0.3583 - learning_rate: 1.4412e-05
# Epoch 50/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 19s 176ms/step - accuracy: 0.9396 - loss: 0.1933 - val_accuracy: 0.8993 - val_loss: 0.3550 - learning_rate: 1.1529e-05
# Epoch 51/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 19s 174ms/step - accuracy: 0.9490 - loss: 0.1670 - val_accuracy: 0.9005 - val_loss: 0.3547 - learning_rate: 9.2234e-06
# Epoch 52/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 19s 177ms/step - accuracy: 0.9451 - loss: 0.1687 - val_accuracy: 0.8987 - val_loss: 0.3567 - learning_rate: 7.3787e-06
# Epoch 53/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 19s 174ms/step - accuracy: 0.9439 - loss: 0.1797 - val_accuracy: 0.8993 - val_loss: 0.3581 - learning_rate: 5.9030e-06
# Epoch 54/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 19s 173ms/step - accuracy: 0.9438 - loss: 0.1786 - val_accuracy: 0.8993 - val_loss: 0.3598 - learning_rate: 4.7224e-06
# Epoch 55/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 19s 172ms/step - accuracy: 0.9389 - loss: 0.1887 - val_accuracy: 0.8987 - val_loss: 0.3593 - learning_rate: 3.7779e-06
# Epoch 56/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 19s 175ms/step - accuracy: 0.9435 - loss: 0.1730 - val_accuracy: 0.8976 - val_loss: 0.3568 - learning_rate: 3.0223e-06
# Epoch 57/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 19s 172ms/step - accuracy: 0.9474 - loss: 0.1694 - val_accuracy: 0.8981 - val_loss: 0.3571 - learning_rate: 2.4179e-06
# Epoch 58/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 19s 171ms/step - accuracy: 0.9448 - loss: 0.1768 - val_accuracy: 0.8976 - val_loss: 0.3568 - learning_rate: 1.9343e-06
# Epoch 59/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 18s 171ms/step - accuracy: 0.9484 - loss: 0.1599 - val_accuracy: 0.8987 - val_loss: 0.3561 - learning_rate: 1.5474e-06
# Epoch 60/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 19s 174ms/step - accuracy: 0.9498 - loss: 0.1642 - val_accuracy: 0.8981 - val_loss: 0.3569 - learning_rate: 1.2379e-06
# Epoch 61/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 19s 173ms/step - accuracy: 0.9497 - loss: 0.1629 - val_accuracy: 0.8976 - val_loss: 0.3567 - learning_rate: 9.9035e-07
# Epoch 62/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 18s 171ms/step - accuracy: 0.9437 - loss: 0.1671 - val_accuracy: 0.8976 - val_loss: 0.3567 - learning_rate: 7.9228e-07
# Epoch 63/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 18s 171ms/step - accuracy: 0.9480 - loss: 0.1693 - val_accuracy: 0.8976 - val_loss: 0.3565 - learning_rate: 6.3383e-07
# Epoch 64/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 19s 173ms/step - accuracy: 0.9470 - loss: 0.1653 - val_accuracy: 0.8970 - val_loss: 0.3566 - learning_rate: 5.0706e-07
# Epoch 65/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 18s 169ms/step - accuracy: 0.9445 - loss: 0.1770 - val_accuracy: 0.8976 - val_loss: 0.3562 - learning_rate: 4.0565e-07
# Epoch 66/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 18s 171ms/step - accuracy: 0.9391 - loss: 0.1867 - val_accuracy: 0.8976 - val_loss: 0.3570 - learning_rate: 3.2452e-07
# Epoch 67/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 19s 173ms/step - accuracy: 0.9492 - loss: 0.1731 - val_accuracy: 0.8976 - val_loss: 0.3572 - learning_rate: 2.5961e-07
# Epoch 68/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 19s 172ms/step - accuracy: 0.9493 - loss: 0.1630 - val_accuracy: 0.8976 - val_loss: 0.3561 - learning_rate: 2.0769e-07
# Epoch 69/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 19s 174ms/step - accuracy: 0.9413 - loss: 0.1787 - val_accuracy: 0.8976 - val_loss: 0.3565 - learning_rate: 1.6615e-07
# Epoch 70/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 19s 176ms/step - accuracy: 0.9482 - loss: 0.1642 - val_accuracy: 0.8970 - val_loss: 0.3572 - learning_rate: 1.3292e-07
# Epoch 71/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 19s 172ms/step - accuracy: 0.9436 - loss: 0.1696 - val_accuracy: 0.8981 - val_loss: 0.3565 - learning_rate: 1.0634e-07
# Epoch 72/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 18s 170ms/step - accuracy: 0.9428 - loss: 0.1695 - val_accuracy: 0.8981 - val_loss: 0.3564 - learning_rate: 8.5071e-08
# Epoch 73/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 19s 172ms/step - accuracy: 0.9477 - loss: 0.1681 - val_accuracy: 0.8970 - val_loss: 0.3577 - learning_rate: 6.8056e-08
# Epoch 74/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 18s 171ms/step - accuracy: 0.9446 - loss: 0.1683 - val_accuracy: 0.8976 - val_loss: 0.3571 - learning_rate: 5.4445e-08
# Epoch 75/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 18s 169ms/step - accuracy: 0.9421 - loss: 0.1761 - val_accuracy: 0.8970 - val_loss: 0.3570 - learning_rate: 4.3556e-08
# Epoch 76/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 18s 170ms/step - accuracy: 0.9433 - loss: 0.1798 - val_accuracy: 0.8970 - val_loss: 0.3564 - learning_rate: 3.4845e-08
# Epoch 77/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 19s 172ms/step - accuracy: 0.9406 - loss: 0.1932 - val_accuracy: 0.8976 - val_loss: 0.3576 - learning_rate: 2.7876e-08
# Epoch 78/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 19s 173ms/step - accuracy: 0.9467 - loss: 0.1556 - val_accuracy: 0.8970 - val_loss: 0.3567 - learning_rate: 2.2301e-08
# Epoch 79/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 18s 170ms/step - accuracy: 0.9471 - loss: 0.1736 - val_accuracy: 0.8970 - val_loss: 0.3566 - learning_rate: 1.7841e-08
# Epoch 80/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 18s 171ms/step - accuracy: 0.9425 - loss: 0.1741 - val_accuracy: 0.8976 - val_loss: 0.3565 - learning_rate: 1.4272e-08
# Epoch 81/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 18s 170ms/step - accuracy: 0.9458 - loss: 0.1727 - val_accuracy: 0.8976 - val_loss: 0.3561 - learning_rate: 1.1418e-08
# Epoch 82/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 18s 170ms/step - accuracy: 0.9435 - loss: 0.1688 - val_accuracy: 0.8976 - val_loss: 0.3566 - learning_rate: 9.1344e-09
# Epoch 83/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 18s 170ms/step - accuracy: 0.9392 - loss: 0.1766 - val_accuracy: 0.8970 - val_loss: 0.3574 - learning_rate: 7.3075e-09
# Epoch 84/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 18s 170ms/step - accuracy: 0.9480 - loss: 0.1667 - val_accuracy: 0.8970 - val_loss: 0.3575 - learning_rate: 5.8460e-09
# Epoch 85/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 19s 173ms/step - accuracy: 0.9451 - loss: 0.1688 - val_accuracy: 0.8976 - val_loss: 0.3567 - learning_rate: 4.6768e-09
# Epoch 86/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 18s 171ms/step - accuracy: 0.9481 - loss: 0.1562 - val_accuracy: 0.8981 - val_loss: 0.3564 - learning_rate: 3.7414e-09
# Epoch 87/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 18s 171ms/step - accuracy: 0.9474 - loss: 0.1644 - val_accuracy: 0.8970 - val_loss: 0.3568 - learning_rate: 2.9932e-09
# Epoch 88/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 18s 169ms/step - accuracy: 0.9453 - loss: 0.1712 - val_accuracy: 0.8970 - val_loss: 0.3571 - learning_rate: 2.3945e-09
# Epoch 89/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 18s 171ms/step - accuracy: 0.9393 - loss: 0.1823 - val_accuracy: 0.8970 - val_loss: 0.3572 - learning_rate: 1.9156e-09
# Epoch 90/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 19s 172ms/step - accuracy: 0.9441 - loss: 0.1725 - val_accuracy: 0.8970 - val_loss: 0.3566 - learning_rate: 1.5325e-09
# Epoch 91/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 18s 170ms/step - accuracy: 0.9477 - loss: 0.1654 - val_accuracy: 0.8976 - val_loss: 0.3566 - learning_rate: 1.2260e-09
# Epoch 92/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 19s 173ms/step - accuracy: 0.9497 - loss: 0.1582 - val_accuracy: 0.8981 - val_loss: 0.3566 - learning_rate: 9.8080e-10
# Epoch 93/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 19s 173ms/step - accuracy: 0.9441 - loss: 0.1680 - val_accuracy: 0.8970 - val_loss: 0.3568 - learning_rate: 7.8464e-10
# Epoch 94/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 18s 169ms/step - accuracy: 0.9399 - loss: 0.1821 - val_accuracy: 0.8976 - val_loss: 0.3568 - learning_rate: 6.2771e-10
# Epoch 95/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 18s 168ms/step - accuracy: 0.9425 - loss: 0.1729 - val_accuracy: 0.8970 - val_loss: 0.3568 - learning_rate: 5.0217e-10
# Epoch 96/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 18s 170ms/step - accuracy: 0.9434 - loss: 0.1851 - val_accuracy: 0.8970 - val_loss: 0.3572 - learning_rate: 4.0173e-10
# Epoch 97/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 18s 170ms/step - accuracy: 0.9493 - loss: 0.1607 - val_accuracy: 0.8970 - val_loss: 0.3569 - learning_rate: 3.2139e-10
# Epoch 98/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 18s 171ms/step - accuracy: 0.9422 - loss: 0.1718 - val_accuracy: 0.8976 - val_loss: 0.3571 - learning_rate: 2.5711e-10
# Epoch 99/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 19s 174ms/step - accuracy: 0.9467 - loss: 0.1640 - val_accuracy: 0.8976 - val_loss: 0.3562 - learning_rate: 2.0569e-10
# Epoch 100/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 19s 173ms/step - accuracy: 0.9432 - loss: 0.1697 - val_accuracy: 0.8981 - val_loss: 0.3566 - learning_rate: 1.6455e-10
# Test Accuracy: 89.81%
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#        angry       0.94      0.91      0.92       225
#         calm       0.92      0.93      0.93       220
#      disgust       0.89      0.88      0.88       235
#         fear       0.91      0.94      0.93       215
#        happy       0.87      0.88      0.88       247
#      neutral       0.74      0.91      0.81        98
#          sad       0.89      0.83      0.86       230
#     surprise       0.95      0.91      0.93       258
#
#     accuracy                           0.90      1728
#    macro avg       0.89      0.90      0.89      1728
# weighted avg       0.90      0.90      0.90      1728

# %%
model.save('speech_emotion_recognition_model.hdf5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
